# %% [markdown]
# # RhoChi refinement

# %%
import cryspy
cryspy.rhochi_refinement()
# Out:
# **********************************************************************
#                    RhoChi program. Console version.
# **********************************************************************
# Before refinement:
#
#
# Refined parameters -- before:
#
# -3.468() (name: _atom_site_magnetism_aniso_chi_11, refinement: True)
# ***  Error ***
# Can not find coefficients <j0> for 'Fe'.
#  It is setted as 0.
# ***  Error ***
# Can not find coefficients <j2> for 'Fe.
#  It is setted as 0.'
# starting chi_sq/n: 10.30 (n = 381).
#
# refinement started for parameters:
# aniso_chi_11       chi_sq
# Optimization terminated successfully.
#          Current function value: 10.298428
#          Iterations: 0
#          Function evaluations: 3
#          Gradient evaluations: 1
# refinement complete, time 0.45 sec.
#
# final chi_sq/n: 10.30
# started chi_sq/n: 10.30
# After refinement:
#
# RhoChi:
#  label:
#  file_out:
#
#  Crystals:
# Crystal:
# label: Fe3O4
#
# Cell:
# ...
