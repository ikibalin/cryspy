# %%
import cryspy
f_1 = "./full.rcif"
f_2 = "./full_2.rcif"
cryspy.rhochi_refinement()
# Out:
# **********************************************************************
#                    RhoChi program. Console version.
# **********************************************************************
# Before refinement:
#
#
# Refined parameters -- before:
#
# 3.565() (name: _atom_site_magnetism_aniso_chi_11, refinement: True)
# 3.587() (name: _atom_site_magnetism_aniso_chi_12, refinement: True)
# starting chi_sq/n: 10.91 (n = 94).
#
# refinement started for parameters:
# aniso_chi_11 aniso_chi_12       chi_sq
#      3.56539      3.58701
#      3.56545      3.58717
# Optimization terminated successfully.
#          Current function value: 10.908157
#          Iterations: 2
#          Function evaluations: 20
#          Gradient evaluations: 5
# refinement complete, time 0.17 sec.
#
# final chi_sq/n: 10.91
# started chi_sq/n: 10.91
# After refinement:
#
# RhoChi:
#  label:
#  file_out:
#
#  Crystals:
# Crystal:
# label: Ho2Ti2O7
#
# Cell:
#  a: 10.2 (name: _cell_length_a)
# ...
