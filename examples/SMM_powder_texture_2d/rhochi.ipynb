# %% [markdown]
# # RhoChi refinement

# %%
import cryspy
f_1 = "full.rcif"
f_2 = "full_2.rcif"
cryspy.rhochi_refinement()
# Out:
# **********************************************************************
#                    RhoChi program. Console version.
# **********************************************************************
# Before refinement:
#
#
# Refined parameters -- before:
#
# 0.0001868() (name: _pd2d_phase_scale, refinement: True)
# ***  Error ***
# Can not find coefficients <j0> for 'Cl'.
#  It is setted as 0.
# ***  Error ***
# Can not find coefficients <j2> for 'Cl.
#  It is setted as 0.'
# ***  Error ***
# Can not find coefficients <j0> for 'Cl'.
#  It is setted as 0.
# ***  Error ***
# Can not find coefficients <j2> for 'Cl.
#  It is setted as 0.'
# ***  Error ***
# Can not find coefficients <j0> for 'S'.
#  It is setted as 0.
# ***  Error ***
# Can not find coefficients <j2> for 'S.
#  It is setted as 0.'
# ***  Error ***
# Can not find coefficients <j0> for 'S'.
#  It is setted as 0.
# ***  Error ***
# Can not find coefficients <j2> for 'S.
#  It is setted as 0.'
# ***  Error ***
# ...
