# %% [markdown]
# # RhoChi refinement

# %%
import cryspy
f_1 = "full_2.rcif"
f_2 = "full_2.rcif"
cryspy.rhochi_refinement()
# Out:
# **********************************************************************
#                    RhoChi program. Console version.
# **********************************************************************
# Before refinement:
#
#
# Refined parameters -- before:
#
# -3.991() (name: _atom_site_magnetism_aniso_chi_11, refinement: True)
# 3.9() (name: _atom_site_magnetism_aniso_chi_11, refinement: True)
# -202.11() (name: _pd2d_background_2theta_phi_intensity, refinement: True)
# -491.0() (name: _pd2d_background_2theta_phi_intensity, refinement: True)
# starting chi_sq/n: 2.21 (n = 25553).
#
# refinement started for parameters:
# aniso_chi_11 aniso_chi_11 hi_intensity hi_intensity       chi_sq
#     -3.99149      3.90084   -202.11000   -491.00001
#     -3.99144      3.90082   -202.11000   -491.00002
#     -3.99137      3.90084   -202.11001   -491.00004
#     -3.99126      3.90091   -202.11002   -491.00009
#     -3.99120      3.90096   -202.11002   -491.00012
# ...
